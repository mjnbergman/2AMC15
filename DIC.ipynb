# %%
# from google.colab import drive
# drive.mount('/content/drive')

# import os
# os.chdir("drive/My Drive/Data Intelligence Challenge/2AMC15")

# !pip install keras-rl

# %%
# Imports
from agents.PPOAgent import BallerAgent

# Parameters
MAX_ITER = 100
NR_EPOCHS = 1000
T = 100

DRAW = True
SAVE_IMAGES = False
LOAD_MODEL = False

agent = BallerAgent(DRAW=DRAW, SAVE=SAVE_IMAGES, LOAD=LOAD_MODEL)
agent.train(nr_epochs=NR_EPOCHS, T=T)
# Out:
# c:\Users\Max.van.den.Hoven\Anaconda3\envs\DIC2\lib\site-packages\tensorflow_probability\python\__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# RESET!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 84, 84, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 82, 82, 8)    80          ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 41, 41, 8)    0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 40, 40, 16)   528         ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 20, 20, 16)  0           ['conv2d_1[0][0]']
#
# ...
